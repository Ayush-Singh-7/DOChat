# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayush-Singh-7/DOChat/blob/master/Musk_Non_Musk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import tensorflow as tf
# Out:
# TensorFlow 2.x selected.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
trainDataFilePath = '/content/drive/My Drive/ML dataset/musk_non-musk.csv'

# %%
train = pd.read_csv(trainDataFilePath)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6598 entries, 0 to 6597
# Columns: 170 entries, ID to class
# dtypes: int64(168), object(2)
# memory usage: 8.6+ MB

# %%
train.describe()
# Out:
#                ID           f1  ...         f166        class
# count  6598.00000  6598.000000  ...  6598.000000  6598.000000
# mean   3299.50000    58.945135  ...    41.770233     0.154138
# std    1904.82287    53.249007  ...    94.116085     0.361108
# min       1.00000   -31.000000  ...  -471.000000     0.000000
# 25%    1650.25000    37.000000  ...    -9.000000     0.000000
# 50%    3299.50000    44.000000  ...    27.000000     0.000000
# 75%    4948.75000    53.000000  ...   119.000000     0.000000
# max    6598.00000   292.000000  ...   367.000000     1.000000
#
# [8 rows x 168 columns]

# %%
train.head()
# Out:
#    ID molecule_name conformation_name  f1   f2  ...  f163  f164  f165  f166  class
# 0   1      MUSK-211           211_1+1  46 -108  ...   156   -50  -112    96      1
# 1   2      MUSK-211          211_1+10  41 -188  ...   169   -61  -136    79      1
# 2   3      MUSK-211          211_1+11  46 -194  ...   165   -67  -145    39      1
# 3   4      MUSK-211          211_1+12  41 -188  ...   168   -60  -135    80      1
# 4   5      MUSK-211          211_1+13  41 -188  ...   168   -60  -135    80      1
#
# [5 rows x 170 columns]

# %%
train.tail()
# Out:
#         ID  molecule_name conformation_name  f1  ...  f164  f165  f166  class
# 6593  6594  NON-MUSK-jp13          jp13_2+5  51  ...   -44  -115   118      0
# 6594  6595  NON-MUSK-jp13          jp13_2+6  44  ...   -66  -144    -5      0
# 6595  6596  NON-MUSK-jp13          jp13_2+7  44  ...   -66  -144    -6      0
# 6596  6597  NON-MUSK-jp13          jp13_2+8  51  ...   -44  -116   117      0
# 6597  6598  NON-MUSK-jp13          jp13_2+9  51  ...   -44  -115   118      0
#
# [5 rows x 170 columns]

# %%
train.apply (lambda x: sum(x.isnull()))
# Out:
# ID                   0
# molecule_name        0
# conformation_name    0
# f1                   0
# f2                   0
#                     ..
# f163                 0
# f164                 0
# f165                 0
# f166                 0
# class                0
# Length: 170, dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
corr = train.corr()
plt.figure(figsize = (25,15))
cmap = sns.diverging_palette(250, 100, as_cmap=True)
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .82})
plt.title('Heatmap of Correlation Matrix')
# Out:
# Text(0.5, 1, 'Heatmap of Correlation Matrix')

# %%
train["class"].value_counts()
# Out:
# 0    5581
# 1    1017
# Name: class, dtype: int64

# %%
#library for resampling data
from imblearn.over_sampling import SMOTE, ADASYN
from collections import Counter
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
X = train.drop(['ID','molecule_name',	'conformation_name', 'class'], axis=1)
y = train['class']
# print(X.head())
print(X.shape)
# print(y.head())
print(y.shape)
# Out:
# (6598, 166)
# (6598,)

# %%
X_sampled, y_resampled = SMOTE().fit_resample(X,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(sorted(Counter(y).items()))
print(sorted(Counter(y_resampled).items()))

print(X.shape)
print(y.shape)

print(X_sampled.shape)
print(y_resampled.shape)
# Out:
# [(0, 5581), (1, 1017)]
# [(0, 5581), (1, 5581)]
# (6598, 166)
# (6598,)
# (11162, 166)
# (11162,)

# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.optimizers import SGD
from keras.utils import np_utils
from keras.layers import BatchNormalization
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(1671)  # for reproducibility

# network and training
NB_EPOCH = 25
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10   # number of outputs = number of digits
#OPTIMIZER = SGD() # SGD optimizer, explained later in this chapter
N_HIDDEN = 128
VALIDATION_SPLIT=0.2 # how much TRA

# %%
# Initialize the constructor
model = tf.keras.models.Sequential()


# Add an input layer 
model.add(tf.keras.layers.Dense(166, activation='relu', input_shape=(166,)))



# Add one hidden layer 
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.BatchNormalization())

# Add one hidden layer 
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.BatchNormalization())


# Add one hidden layer 
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.BatchNormalization())


# Add one hidden layer 
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.BatchNormalization())


# Add one hidden layer 
model.add(tf.keras.layers.Dense(32, activation='relu'))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.BatchNormalization())




# Add an output layer 
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_14 (Dense)             (None, 166)               27722
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               85504
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# ...

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['binary_accuracy'])

# %%
history = model.fit(X_sampled, y_resampled,
                    batch_size=BATCH_SIZE, epochs=NB_EPOCH,
                    verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Train on 8929 samples, validate on 2233 samples
# Epoch 1/25
# 8929/8929 [==============================] - 4s 393us/sample - loss: 0.5115 - binary_accuracy: 0.7459 - val_loss: 1.4979 - val_binary_accuracy: 0.3139
# Epoch 2/25
# 8929/8929 [==============================] - 1s 57us/sample - loss: 0.2376 - binary_accuracy: 0.9066 - val_loss: 0.2792 - val_binary_accuracy: 0.8482
# Epoch 3/25
# 8929/8929 [==============================] - 0s 54us/sample - loss: 0.1542 - binary_accuracy: 0.9425 - val_loss: 0.0346 - val_binary_accuracy: 0.9884
# Epoch 4/25
# 8929/8929 [==============================] - 1s 56us/sample - loss: 0.1071 - binary_accuracy: 0.9648 - val_loss: 0.0335 - val_binary_accuracy: 0.9884
# Epoch 5/25
# 8929/8929 [==============================] - 0s 53us/sample - loss: 0.0860 - binary_accuracy: 0.9717 - val_loss: 0.1316 - val_binary_accuracy: 0.9503
# Epoch 6/25
# ...

# %%
score = model.evaluate(X_sampled, y_resampled, verbose=VERBOSE)
#print("\nTest score:", score[0])
print('accuracy:', score[1])
# Out:
# 11162/11162 [==============================] - 1s 72us/sample - loss: 0.0126 - binary_accuracy: 0.9954
# accuracy: 0.99543095

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
# demonstration of calculating metrics for a neural network model using sklearn
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
# predict probabilities for test set
yhat_probs = model.predict(X_sampled, verbose=0)
# predict crisp classes for test set
yhat_classes = model.predict_classes(X_sampled, verbose=0)

# %%
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_resampled, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_resampled, yhat_classes)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_resampled, yhat_classes)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_resampled, yhat_classes)
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.995431
# Precision: 0.993750
# Recall: 0.997133
# F1 score: 0.995439

# %%
# kappa
kappa = cohen_kappa_score(y_resampled, yhat_classes)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_resampled, yhat_probs)
print('ROC AUC: %f' % auc)
# confusion matrix
matrix = confusion_matrix(y_resampled, yhat_classes)
print(matrix)
# Out:
# Cohens kappa: 0.990862
# ROC AUC: 0.999856
# [[5546   35]
#  [  16 5565]]

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
